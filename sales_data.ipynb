# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("sales_data.csv.xls")
df
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052  2023-02-03       Bob  North       5053.97             18
# 1          1093  2023-04-21       Bob   West       4384.02             17
# 2          1015  2023-09-21     David  South       4631.23             30
# 3          1072  2023-08-24       Bob  South       2167.94             39
# 4          1061  2023-03-24   Charlie   East       3750.20             13
# ..          ...         ...       ...    ...           ...            ...
# 995        1010  2023-04-15   Charlie  North       4733.88              4
# 996        1067  2023-09-07       Bob  North       4716.36             37
# 997        1018  2023-04-27     David  South       7629.70             17
# 998        1100  2023-12-20     David   West       1629.47             39
# 999        1086  2023-08-16     Alice   East       4923.93             48
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
# Q1. Find the total number of records.

print(len(df))
# or
print(df.shape[0])
# Out:
# 1000
# 1000

# %%
# Q2. Display the number of columns.

print(df.shape[1])
# Out:
# 14

# %%
# Q3. Show the data type of each column.

print(df.dtypes)
# Out:
# Product_ID                int64
# Sale_Date                object
# Sales_Rep                object
# Region                   object
# Sales_Amount            float64
# Quantity_Sold             int64
# Product_Category         object
# Unit_Cost               float64
# Unit_Price              float64
# Customer_Type            object
# Discount                float64
# Payment_Method           object
# Sales_Channel            object
# Region_and_Sales_Rep     object
# dtype: object

# %%
# Q4. Find the number of unique Product_IDs.

print(df["Product_ID"].nunique())
# Out:
# 100

# %%
# Q5. Find the number of unique Sales Representatives.

print(df["Sales_Rep"].nunique())
# Out:
# 5

# %%
# Q6. List all unique Regions.

print(df["Region"].unique())
# Out:
# ['North' 'West' 'South' 'East']

# %%
# Q7. List all Product Categories.

print(df["Product_Category"].unique())
# Out:
# ['Furniture' 'Food' 'Clothing' 'Electronics']

# %%
# Q8. List all Customer Types.

print(df["Customer_Type"].unique())
# Out:
# ['Returning' 'New']

# %%
# Q9. List all Payment Methods.

print(df["Payment_Method"].unique())
# Out:
# ['Cash' 'Bank Transfer' 'Credit Card']

# %%
# Q10. List all Sales Channels.

print(df["Sales_Channel"].unique())
# Out:
# ['Online' 'Retail']

# %%
# Q11. Calculate the total Sales Amount.

print(df["Sales_Amount"].sum())
# Out:
# 5019265.2299999995

# %%
# Q12. Calculate the average Sales Amount.

print(df["Sales_Amount"].mean())
# Out:
# 5019.265229999999

# %%
# Q13. Find the maximum Sales Amount.

print(df["Sales_Amount"].max())
# Out:
# 9989.04

# %%
# Q14. Find the minimum Sales Amount.

print(df["Sales_Amount"].min())
# Out:
# 100.12

# %%
# Q15. Calculate the total Quantity sold.

print(df["Quantity_Sold"].sum())
# Out:
# 25355

# %%
# Q16. Calculate the average Quantity sold.

print(df["Quantity_Sold"].mean())
# Out:
# 25.355

# %%
# Q17. Calculate the total Unit Cost.

print(df["Unit_Cost"].sum())
# Out:
# 2475304.5500000003

# %%
# Q18. Calculate the average Unit Price.

print(df["Unit_Price"].mean())
# Out:
# 2728.44012

# %%
# Q19. Calculate the total Discount given.

print(df["Discount"].sum())
# Out:
# 152.39

# %%
# Q20. Calculate the average Discount.

print(df["Discount"].mean())
# Out:
# 0.15239

# %%
# Q21. Find total Sales Amount by Region.

print(df.groupby("Region")["Sales_Amount"].sum())
# Out:
# Region
# East     1259792.93
# North    1369612.51
# South    1154250.86
# West     1235608.93
# Name: Sales_Amount, dtype: float64

# %%
# Q22. Find average Sales Amount by Region.

print(df.groupby("Region")["Sales_Amount"].mean())
# Out:
# Region
# East     4790.087186
# North    5129.634869
# South    5107.304690
# West     5063.971025
# Name: Sales_Amount, dtype: float64

# %%
# Q23. Find total Sales Amount by Sales Representative.

print(df.groupby("Sales_Rep")["Sales_Amount"].sum())
# Out:
# Sales_Rep
# Alice       965541.77
# Bob        1080990.63
# Charlie     860811.48
# David      1141737.36
# Eve         970183.99
# Name: Sales_Amount, dtype: float64

# %%
# Q24. Find total Quantity sold by Product Category.

print(df.groupby("Product_Category")["Quantity_Sold"].sum())
# Out:
# Product_Category
# Clothing       6922
# Electronics    6096
# Food           5608
# Furniture      6729
# Name: Quantity_Sold, dtype: int64

# %%
# Q25. Find average Discount by Customer Type.

print(df.groupby("Customer_Type")["Discount"].mean())
# Out:
# Customer_Type
# New          0.151726
# Returning    0.153065
# Name: Discount, dtype: float64

# %%
print(df.groupby("Customer_Type")["Discount"].mean())
# Out:
# Customer_Type
# New          0.151726
# Returning    0.153065
# Name: Discount, dtype: float64

# %%
# Q27. Find average Sales Amount by Sales Channel.

print(df.groupby("Sales_Channel")["Sales_Amount"].mean())
# Out:
# Sales_Channel
# Online    5038.594119
# Retail    5000.842383
# Name: Sales_Amount, dtype: float64

# %%
# Q28. Find total Sales Amount by Region and Product Category.

print(df.groupby(["Region", "Product_Category"])["Sales_Amount"].sum())
# Out:
# Region  Product_Category
# East    Clothing            356670.40
#         Electronics         303101.42
#         Food                325864.87
#         Furniture           274156.24
# North   Clothing            372977.22
#         Electronics         342666.29
#         Food                258985.65
#         Furniture           394983.35
# South   Clothing            269517.74
#         Electronics         293663.96
#         Food                301187.51
#         Furniture           289881.65
# West    Clothing            314309.00
#         Electronics         304067.97
#         Food                315735.51
#         Furniture           301496.45
# Name: Sales_Amount, dtype: float64

# %%
# Q29. Find average Unit Price by Product Category.

print(df.groupby("Product_Category")["Unit_Price"].mean())
# Out:
# Product_Category
# Clothing       2721.256381
# Electronics    2795.207195
# Food           2657.811726
# Furniture      2734.065346
# Name: Unit_Price, dtype: float64

# %%
# Q30. Find maximum Sales Amount by Sales Representative.

print(df.groupby("Sales_Rep")["Sales_Amount"].max())
# Out:
# Sales_Rep
# Alice      9972.66
# Bob        9956.75
# Charlie    9972.11
# David      9989.04
# Eve        9933.22
# Name: Sales_Amount, dtype: float64

# %%
# Q31. Display all sales where Sales Amount > 5000.

print(df[df["Sales_Amount"] > 5000])
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052  2023-02-03       Bob  North       5053.97             18
# 7          1087  2023-01-06       Eve  South       7698.92             46
# 9          1075  2023-10-09   Charlie   West       8239.58             18
# 10         1088  2023-11-16       Eve  North       8518.45             13
# 12         1024  2023-11-11       Eve   West       6607.80             21
# ..          ...         ...       ...    ...           ...            ...
# 982        1074  2023-12-16       Bob  North       6310.56             19
# 983        1039  2023-08-01       Eve   West       7527.63             36
# 989        1025  2023-12-30     David   West       9215.32             28
# 994        1068  2023-04-06     Alice  South       9093.50             31
# 997        1018  2023-04-27     David  South       7629.70             17
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
# Q32. Display all Furniture sales.

print(df[df["Product_Category"] == "Furniture"])
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052  2023-02-03       Bob  North       5053.97             18
# 1          1093  2023-04-21       Bob   West       4384.02             17
# 6          1083  2023-04-11       Bob   West        618.31             29
# 7          1087  2023-01-06       Eve  South       7698.92             46
# 8          1075  2023-06-29     David  South       4223.39             30
# ..          ...         ...       ...    ...           ...            ...
# 984        1057  2023-06-08   Charlie   East       1605.28             43
# 986        1086  2023-10-20     David  South       3577.07             32
# 987        1090  2023-01-04       Eve  North       1028.39             14
# 991        1013  2023-06-01   Charlie   East       2985.46             16
# 993        1025  2023-06-26     David  North       2457.65             47
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
# Q33. Display all sales from the North region.

print(df[df["Region"] == "North"])
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052  2023-02-03       Bob  North       5053.97             18
# 10         1088  2023-11-16       Eve  North       8518.45             13
# 15         1053  2023-10-16       Bob  North       2235.83             48
# 16         1002  2023-05-30     David  North       6810.35             17
# 20         1002  2023-04-22       Eve  North       6551.23              9
# ..          ...         ...       ...    ...           ...            ...
# 987        1090  2023-01-04       Eve  North       1028.39             14
# 988        1044  2023-08-08     Alice  North       4912.69             18
# 993        1025  2023-06-26     David  North       2457.65             47
# 995        1010  2023-04-15   Charlie  North       4733.88              4
# 996        1067  2023-09-07       Bob  North       4716.36             37
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
# Q34. Display all Returning customers.

print(df[df["Customer_Type"] == "Returning"])
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052  2023-02-03       Bob  North       5053.97             18
# 1          1093  2023-04-21       Bob   West       4384.02             17
# 2          1015  2023-09-21     David  South       4631.23             30
# 6          1083  2023-04-11       Bob   West        618.31             29
# 11         1100  2023-08-14       Bob   West       2198.74             43
# ..          ...         ...       ...    ...           ...            ...
# 991        1013  2023-06-01   Charlie   East       2985.46             16
# 994        1068  2023-04-06     Alice  South       9093.50             31
# 995        1010  2023-04-15   Charlie  North       4733.88              4
# 997        1018  2023-04-27     David  South       7629.70             17
# 999        1086  2023-08-16     Alice   East       4923.93             48
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
# Q36. Display all Credit Card payment transactions.

print(df[df["Payment_Method"] == "Credit Card"])
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 3          1072  2023-08-24       Bob  South       2167.94             39
# 4          1061  2023-03-24   Charlie   East       3750.20             13
# 17         1088  2023-10-04       Bob   East       6116.75             40
# 25         1076  2023-12-16       Eve   East       7160.75             30
# 31         1059  2023-08-31     Alice  North       1203.97             35
# ..          ...         ...       ...    ...           ...            ...
# 987        1090  2023-01-04       Eve  North       1028.39             14
# 989        1025  2023-12-30     David   West       9215.32             28
# 991        1013  2023-06-01   Charlie   East       2985.46             16
# 993        1025  2023-06-26     David  North       2457.65             47
# 994        1068  2023-04-06     Alice  South       9093.50             31
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
# Q37. Display all Online sales.

print(df[df["Sales_Channel"] == "Online"])
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052  2023-02-03       Bob  North       5053.97             18
# 4          1061  2023-03-24   Charlie   East       3750.20             13
# 5          1021  2023-02-11   Charlie   West       3761.15             32
# 6          1083  2023-04-11       Bob   West        618.31             29
# 7          1087  2023-01-06       Eve  South       7698.92             46
# ..          ...         ...       ...    ...           ...            ...
# 993        1025  2023-06-26     David  North       2457.65             47
# 995        1010  2023-04-15   Charlie  North       4733.88              4
# 997        1018  2023-04-27     David  South       7629.70             17
# 998        1100  2023-12-20     David   West       1629.47             39
# 999        1086  2023-08-16     Alice   East       4923.93             48
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
# Q38. Display all Retail sales.

print(df[df["Sales_Channel"] == "Retail"])
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 1          1093  2023-04-21       Bob   West       4384.02             17
# 2          1015  2023-09-21     David  South       4631.23             30
# 3          1072  2023-08-24       Bob  South       2167.94             39
# 10         1088  2023-11-16       Eve  North       8518.45             13
# 12         1024  2023-11-11       Eve   West       6607.80             21
# ..          ...         ...       ...    ...           ...            ...
# 989        1025  2023-12-30     David   West       9215.32             28
# 990        1017  2023-01-20       Bob   East        496.59             29
# 991        1013  2023-06-01   Charlie   East       2985.46             16
# 994        1068  2023-04-06     Alice  South       9093.50             31
# 996        1067  2023-09-07       Bob  North       4716.36             37
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
# Q39. Display all records where Discount > 20%.

print(df[df["Discount"] > 20])
# Out:
# Empty DataFrame
# Columns: [Product_ID, Sale_Date, Sales_Rep, Region, Sales_Amount, Quantity_Sold, Product_Category, Unit_Cost, Unit_Price, Customer_Type, Discount, Payment_Method, Sales_Channel, Region_and_Sales_Rep]
# Index: []

# %%
# Q40. Display all records where Quantity > 30.

print(df[df["Quantity_Sold"] > 30])
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 3          1072  2023-08-24       Bob  South       2167.94             39
# 5          1021  2023-02-11   Charlie   West       3761.15             32
# 7          1087  2023-01-06       Eve  South       7698.92             46
# 11         1100  2023-08-14       Bob   West       2198.74             43
# 15         1053  2023-10-16       Bob  North       2235.83             48
# ..          ...         ...       ...    ...           ...            ...
# 993        1025  2023-06-26     David  North       2457.65             47
# 994        1068  2023-04-06     Alice  South       9093.50             31
# 996        1067  2023-09-07       Bob  North       4716.36             37
# 998        1100  2023-12-20     David   West       1629.47             39
# 999        1086  2023-08-16     Alice   East       4923.93             48
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
# Q41. Which Sales Representative generated the highest total revenue.

print(df.groupby("Sales_Rep")["Sales_Amount"].sum().idxmax())
# Out:
# David

# %%
# Q42. Which Region generated the highest revenue.

print(df.groupby("Region")["Sales_Amount"].sum().idxmax())
# Out:
# North

# %%
# Q43. Which Product Category sold the highest quantity.

print(df.groupby("Product_Category")["Quantity_Sold"].sum().idxmax())
# Out:
# Clothing

# %%
# Q44. Which Customer Type generated the highest revenue.

print(df.groupby("Customer_Type")["Sales_Amount"].sum().idxmax())
# Out:
# Returning

# %%
# Q45. Which Payment Method was used the most.

print(df["Payment_Method"].value_counts().idxmax())
# Out:
# Credit Card

# %%
# Q46. Which Sales Channel generated the highest average sales.

print(df.groupby("Sales_Channel")["Sales_Amount"].mean().idxmax())
# Out:
# Online

# %%
# Q47. Create a new column Profit = (Unit_Price - Unit_Cost) × Quantity.

df["Profit"] = (df["Unit_Price"] - df["Unit_Cost"]) * df["Quantity_Sold"]

print(df.head())
# Out:
#    Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0        1052  2023-02-03       Bob  North       5053.97             18
# 1        1093  2023-04-21       Bob   West       4384.02             17
# 2        1015  2023-09-21     David  South       4631.23             30
# 3        1072  2023-08-24       Bob  South       2167.94             39
# 4        1061  2023-03-24   Charlie   East       3750.20             13
#
#   Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# 0        Furniture     152.75      267.22     Returning      0.09
# 1        Furniture    3816.39     4209.44     Returning      0.11
# 2             Food     261.56      371.40     Returning      0.20
# 3         Clothing    4330.03     4467.75           New      0.02
# 4      Electronics     637.37      692.71           New      0.08
#
#   Payment_Method Sales_Channel Region_and_Sales_Rep   Profit
# 0           Cash        Online            North-Bob  2060.46
# ...

# %%
# Q48. Find the Top 10 most profitable transactions.

print(df.sort_values(by="Profit", ascending=False).head(10))
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 425        1008  2023-12-08     Alice  South       3197.78             49
# 962        1090  2023-10-15   Charlie  South       9702.27             48
# 433        1066  2023-09-25       Eve   East       7391.70             47
# 555        1012  2023-06-20     Alice  South       2019.24             47
# 66         1035  2023-05-22     Alice  South       3780.22             45
# 22         1060  2023-12-16       Eve   East       3224.71             44
# 721        1061  2023-12-22     Alice  North       1990.17             45
# 149        1014  2023-02-11     David   West        823.51             44
# 667        1050  2023-05-17       Bob  North       2254.91             45
# 221        1081  2023-04-16   Charlie   West       2896.71             44
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# 425      Electronics    2907.22     3385.61           New      0.13
# ...

# %%
# Q49. Analyze monthly sales trends using Sale_Date.

df["Sale_Date"] = pd.to_datetime(df["Sale_Date"])

monthly_sales = df.groupby(df["Sale_Date"].dt.to_period("M"))["Sales_Amount"].sum()

print(monthly_sales)
# Out:
# Sale_Date
# 2023-01    476092.36
# 2023-02    368919.36
# 2023-03    402638.77
# 2023-04    438992.61
# 2023-05    389078.76
# 2023-06    418458.34
# 2023-07    374242.88
# 2023-08    443171.28
# 2023-09    367837.60
# 2023-10    460378.78
# 2023-11    467482.90
# 2023-12    392643.58
# 2024-01     19328.01
# Freq: M, Name: Sales_Amount, dtype: float64

# %%
# Q50. Create an EDA Dashboard containing:
# • Total Sales
# • Total Profit
# • Region-wise Sales
# • Category-wise Sales
# • Monthly Sales Trend
# • Sales by Sales Representative
# • Customer Type Distribution
# • Payment Method Distribution
# • Sales Channel Distribution
# • Discount Analysis

df["Profit"] = (df["Unit_Price"] - df["Unit_Cost"]) * df["Quantity_Sold"]

df["Sale_Date"] = pd.to_datetime(df["Sale_Date"])

monthly_sales = df.groupby(df["Sale_Date"].dt.to_period("M"))["Sales_Amount"].sum()

plt.figure(figsize=(18, 12))

plt.subplot(3,3,1)
df.groupby("Region")["Sales_Amount"].sum().plot(kind="bar")
plt.title("Region-wise Sales")

plt.subplot(3,3,2)
df.groupby("Product_Category")["Sales_Amount"].sum().plot(kind="bar")
plt.title("Category-wise Sales")

plt.subplot(3,3,3)
monthly_sales.plot(kind="line", marker="o")
plt.title("Monthly Sales Trend")

plt.subplot(3,3,4)
df.groupby("Sales_Rep")["Sales_Amount"].sum().plot(kind="bar")
plt.title("Sales by Sales Representative")

plt.subplot(3,3,5)
df["Customer_Type"].value_counts().plot(kind="pie", autopct="%1.1f%%")
plt.title("Customer Type Distribution")
plt.ylabel("")

plt.subplot(3,3,6)
df["Payment_Method"].value_counts().plot(kind="pie", autopct="%1.1f%%")
plt.title("Payment Method Distribution")
plt.ylabel("")

plt.subplot(3,3,7)
df["Sales_Channel"].value_counts().plot(kind="bar")
plt.title("Sales Channel Distribution")

plt.subplot(3,3,8)
plt.hist(df["Discount"], bins=10)
plt.title("Discount Analysis")

plt.subplot(3,3,9)
plt.hist(df["Profit"], bins=10)
plt.title("Profit Distribution")

plt.tight_layout()
plt.show()

print("Total Sales:", df["Sales_Amount"].sum())
print("Total Profit:", df["Profit"].sum())
# Out:
# Total Sales: 5019265.2299999995
# Total Profit: 6487847.07
