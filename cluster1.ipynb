# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans 

data = {
    "age":[20,22,25,27,30,32,35,38,40,42],
    "income":[25000,27000,29000,31000,60000,62000,64000,66000,68000,70000]
}

df=pd.DataFrame(data)
print(df)

x=df[["age","income"]]

model = KMeans(n_clusters=3, random_state=42)

df["cluster"] = model.fit_predict(x)

print(df)
# Out:
#    age  income
# 0   20   25000
# 1   22   27000
# 2   25   29000
# 3   27   31000
# 4   30   60000
# 5   32   62000
# 6   35   64000
# 7   38   66000
# 8   40   68000
# 9   42   70000
#    age  income  cluster
# 0   20   25000        2
# 1   22   27000        2
# 2   25   29000        0
# 3   27   31000        0
# 4   30   60000        1
# 5   32   62000        1
# 6   35   64000        1
# 7   38   66000        1
# 8   40   68000        1
# 9   42   70000        1
# C:\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

df=pd.read_csv("customer_segmentation_100_records.csv")
print(df)
# Out:
#    Customer_ID  Age  Gender  Annual_Income  Spending_Score  Purchase_Frequency
# 0         C001   21  Female          21700              94                  14
# 1         C002   22    Male          23400              93                  13
# 2         C003   23  Female          25100              92                  12
# 3         C004   24    Male          26800              91                  11
# 4         C005   25  Female          28500              90                  10
# ..         ...  ...     ...            ...             ...                 ...
# 95        C096   46    Male         183200              49                   9
# 96        C097   47  Female         184900              48                   8
# 97        C098   48    Male         186600              47                   7
# 98        C099   49  Female         188300              46                   6
# 99        C100   50    Male         190000              95                   5
#
# [100 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer_ID         100 non-null    object
#  1   Age                 100 non-null    int64
#  2   Gender              100 non-null    object
#  3   Annual_Income       100 non-null    int64
#  4   Spending_Score      100 non-null    int64
#  5   Purchase_Frequency  100 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 4.8+ KB

# %%
x=df[["Age","Annual_Income","Spending_Score"]]

model = KMeans(n_clusters=3, random_state=42)

df["cluster"] = model.fit_predict(x)

pd.set_option('display.max_rows', None)
display(df)
# Out:
# C:\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
#    Customer_ID  Age  Gender  Annual_Income  Spending_Score  \
# 0         C001   21  Female          21700              94
# 1         C002   22    Male          23400              93
# 2         C003   23  Female          25100              92
# 3         C004   24    Male          26800              91
# 4         C005   25  Female          28500              90
# 5         C006   26    Male          30200              89
# 6         C007   27  Female          31900              88
# 7         C008   28    Male          33600              87
# 8         C009   29  Female          35300              86
# 9         C010   30    Male          37000              85
# 10        C011   31  Female          38700              84
# 11        C012   32    Male          40400              83
# 12        C013   33  Female          42100              82
# 13        C014   34    Male          43800              81
# 14        C015   35  Female          45500              80
# 15        C016   36    Male          47200              79
# 16        C017   37  Female          48900              78
# 17        C018   38    Male          50600              77
# 18        C019   39  Female          52300              76
# 19        C020   40    Male          54000              75
# 20        C021   41  Female          55700              74
# 21        C022   42    Male          57400              73
# 22        C023   43  Female          59100              72
# 23        C024   44    Male          60800              71
# 24        C025   45  Female          62500              70
# 25        C026   46    Male          64200              69
# 26        C027   47  Female          65900              68
# 27        C028   48    Male          67600              67
# 28        C029   49  Female          69300              66
# 29        C030   50    Male          71000              65
# 30        C031   51  Female          72700              64
# 31        C032   52    Male          74400              63
# 32        C033   53  Female          76100              62
# 33        C034   54    Male          77800              61
# 34        C035   20  Female          79500              60
# 35        C036   21    Male          81200              59
# 36        C037   22  Female          82900              58
# 37        C038   23    Male          84600              57
# 38        C039   24  Female          86300              56
# 39        C040   25    Male          88000              55
# 40        C041   26  Female          89700              54
# 41        C042   27    Male          91400              53
# 42        C043   28  Female          93100              52
# 43        C044   29    Male          94800              51
# 44        C045   30  Female          96500              50
# 45        C046   31    Male          98200              49
# 46        C047   32  Female          99900              48
# 47        C048   33    Male         101600              47
# 48        C049   34  Female         103300              46
# 49        C050   35    Male         105000              95
# 50        C051   36  Female         106700              94
# 51        C052   37    Male         108400              93
# 52        C053   38  Female         110100              92
# 53        C054   39    Male         111800              91
# 54        C055   40  Female         113500              90
# 55        C056   41    Male         115200              89
# 56        C057   42  Female         116900              88
# 57        C058   43    Male         118600              87
# 58        C059   44  Female         120300              86
# 59        C060   45    Male         122000              85
# 60        C061   46  Female         123700              84
# 61        C062   47    Male         125400              83
# 62        C063   48  Female         127100              82
# 63        C064   49    Male         128800              81
# 64        C065   50  Female         130500              80
# 65        C066   51    Male         132200              79
# 66        C067   52  Female         133900              78
# 67        C068   53    Male         135600              77
# 68        C069   54  Female         137300              76
# 69        C070   20    Male         139000              75
# 70        C071   21  Female         140700              74
# 71        C072   22    Male         142400              73
# 72        C073   23  Female         144100              72
# 73        C074   24    Male         145800              71
# 74        C075   25  Female         147500              70
# 75        C076   26    Male         149200              69
# 76        C077   27  Female         150900              68
# 77        C078   28    Male         152600              67
# 78        C079   29  Female         154300              66
# 79        C080   30    Male         156000              65
# 80        C081   31  Female         157700              64
# 81        C082   32    Male         159400              63
# 82        C083   33  Female         161100              62
# 83        C084   34    Male         162800              61
# 84        C085   35  Female         164500              60
# 85        C086   36    Male         166200              59
# 86        C087   37  Female         167900              58
# 87        C088   38    Male         169600              57
# 88        C089   39  Female         171300              56
# 89        C090   40    Male         173000              55
# 90        C091   41  Female         174700              54
# 91        C092   42    Male         176400              53
# 92        C093   43  Female         178100              52
# 93        C094   44    Male         179800              51
# 94        C095   45  Female         181500              50
# 95        C096   46    Male         183200              49
# 96        C097   47  Female         184900              48
# 97        C098   48    Male         186600              47
# 98        C099   49  Female         188300              46
# 99        C100   50    Male         190000              95
#
#     Purchase_Frequency  cluster
# 0                   14        2
# 1                   13        2
# 2                   12        2
# 3                   11        2
# 4                   10        2
# 5                    9        2
# 6                    8        2
# 7                    7        2
# 8                    6        2
# 9                    5        2
# 10                   4        2
# 11                   3        2
# 12                   2        2
# 13                   1        2
# 14                  15        2
# 15                  14        2
# 16                  13        2
# 17                  12        2
# 18                  11        2
# 19                  10        2
# 20                   9        2
# 21                   8        2
# 22                   7        2
# 23                   6        2
# 24                   5        2
# 25                   4        2
# 26                   3        2
# 27                   2        2
# 28                   1        2
# 29                  15        2
# 30                  14        2
# 31                  13        2
# 32                  12        0
# 33                  11        0
# 34                  10        0
# 35                   9        0
# 36                   8        0
# 37                   7        0
# 38                   6        0
# 39                   5        0
# 40                   4        0
# 41                   3        0
# 42                   2        0
# 43                   1        0
# 44                  15        0
# 45                  14        0
# 46                  13        0
# 47                  12        0
# 48                  11        0
# 49                  10        0
# 50                   9        0
# 51                   8        0
# 52                   7        0
# 53                   6        0
# 54                   5        0
# 55                   4        0
# 56                   3        0
# 57                   2        0
# 58                   1        0
# 59                  15        0
# 60                  14        0
# 61                  13        0
# 62                  12        0
# 63                  11        0
# 64                  10        0
# 65                   9        0
# 66                   8        1
# 67                   7        1
# 68                   6        1
# 69                   5        1
# 70                   4        1
# 71                   3        1
# 72                   2        1
# 73                   1        1
# 74                  15        1
# 75                  14        1
# 76                  13        1
# 77                  12        1
# 78                  11        1
# 79                  10        1
# 80                   9        1
# 81                   8        1
# 82                   7        1
# 83                   6        1
# 84                   5        1
# 85                   4        1
# 86                   3        1
# 87                   2        1
# 88                   1        1
# 89                  15        1
# 90                  14        1
# 91                  13        1
# 92                  12        1
# 93                  11        1
# 94                  10        1
# 95                   9        1
# 96                   8        1
# 97                   7        1
# 98                   6        1
# 99                   5        1
